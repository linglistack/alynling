# %%
import pandas as pd
import geonamescache as gmc
import random
import numpy as np

# %%
olmkt = pd.read_csv("online_mkt.csv")

# %%
# -----------------------------
# Step 1. Load US states & cities from geonamescache
# -----------------------------
gc = gmc.GeonamesCache()
us_states = gc.get_us_states()      # dict: FIPS -> {name, abbr}
cities = gc.get_cities()            # dict: geonameid -> {name, countrycode, admin1code, ...}

# Build state_name → [cities]
state_to_cities = {s["name"]: [] for s in us_states.values()}
for city in cities.values():
    if city["countrycode"] == "US":
        state_fips = city["admin1code"]
        if state_fips in us_states:
            state_name = us_states[state_fips]["name"]
            state_to_cities[state_name].append(city["name"])

# Drop states with no cities (rare)
state_to_cities = {k: v for k, v in state_to_cities.items() if v}

# -----------------------------
# Step 2. Build Brazil state → U.S. state mapping
# -----------------------------
unique_brazil_states = olmkt["state"].unique()
us_state_names = list(state_to_cities.keys())
random.shuffle(us_state_names)  # optional randomization

state_map = {
    br_state: us_state_names[i % len(us_state_names)]
    for i, br_state in enumerate(unique_brazil_states)
}

# -----------------------------
# Step 3. Build Brazil city → U.S. city mapping
# -----------------------------
city_map = {}
for _, row in olmkt.iterrows():
    br_state, br_city = row["state"], row["city"]
    us_state = state_map[br_state]

    if (br_state, br_city) not in city_map:  # assign once
        city_map[(br_state, br_city)] = random.choice(state_to_cities[us_state])

# -----------------------------
# Step 4. Apply mapping
# -----------------------------
olmkt["us_state"] = olmkt["state"].map(state_map)
olmkt["us_city"] = olmkt.apply(lambda r: city_map[(r["state"], r["city"])], axis=1)

# ----------------------------
# Step 5. Check
# ----------------------------
temp = olmkt.loc[:, olmkt.columns.str.contains("state|city")].drop_duplicates()
temp.sort_values('state')
# Out:
#                          city                state       us_state  \
# 1952                   maceio              alagoas  West Virginia
# 5246                   macapa                amapa       Colorado
# 732                    manaus             amazonas       Missouri
# 4026         feira_de_santana                bahia       Oklahoma
# 366                  salvador                bahia       Oklahoma
# 488                 fortaleza                ceara       New York
# 244                  brasilia     distrito_federal    Mississippi
# 5002                    serra       espirito_santo        Arizona
# 5856               vila_velha       espirito_santo        Arizona
# 4392     aparecida_de_goiania                goias           Iowa
# 1098                  goiania                goias           Iowa
# 1708                 sao_luis             maranhao      Wisconsin
# 4148                   cuiaba          mato_grosso  New Hampshire
# 2196             campo_grande   mato_grosso_do_sul       Kentucky
# 3416               uberlandia         minas_gerais   Pennsylvania
# 610            belo_horizonte         minas_gerais   Pennsylvania
# 4636             juiz_de_fora         minas_gerais   Pennsylvania
# 3782                 contagem         minas_gerais   Pennsylvania
# 1220                    belem                 para         Hawaii
# 4880               ananindeua                 para         Hawaii
# 2684              joao_pessoa              paraiba       Nebraska
# 854                  curitiba               parana     New Mexico
# 4514                 londrina               parana     New Mexico
# 976                    recife           pernambuco       Virginia
# 3294  jaboatao_dos_guararapes           pernambuco       Virginia
# 2440                 teresina                piaui      Louisiana
# 2074          duque_de_caxias       rio_de_janeiro          Idaho
# 2806              nova_iguacu       rio_de_janeiro          Idaho
# 1830              sao_goncalo       rio_de_janeiro          Idaho
# 5612             belford_roxo       rio_de_janeiro          Idaho
# 5734    campos_dos_goytacazes       rio_de_janeiro          Idaho
# 122            rio_de_janeiro       rio_de_janeiro          Idaho
# 5368                  niteroi       rio_de_janeiro          Idaho
# 2318                    natal  rio_grande_do_norte    Connecticut
# 5124            caxias_do_sul    rio_grande_do_sul       Maryland
# 1342             porto_alegre    rio_grande_do_sul       Maryland
# 4758              porto_velho             rondonia          Maine
# 5490            florianopolis       santa_catarina     Washington
# 4270                joinville       santa_catarina     Washington
# 0                   sao_paulo            sao_paulo        Indiana
# 2928      sao_jose_dos_campos            sao_paulo        Indiana
# 3660                 sorocaba            sao_paulo        Indiana
# 3538                   osasco            sao_paulo        Indiana
# 3172           ribeirao_preto            sao_paulo        Indiana
# 3050              santo_andre            sao_paulo        Indiana
# 2562    sao_bernardo_do_campo            sao_paulo        Indiana
# 1586                 campinas            sao_paulo        Indiana
# 1464                guarulhos            sao_paulo        Indiana
# 5978                     maua            sao_paulo        Indiana
# 3904                  aracaju              sergipe   Rhode Island
#
#                  us_city
# 1952         Martinsburg
# 5246            Montrose
# 732         Saint Joseph
# 4026              Duncan
# 366              Shawnee
# 488               Selden
# 244        West Gulfport
# 5002                Mesa
# 5856            Goodyear
# 4392                Ames
# 1098          Des Moines
# 1708          New Berlin
# 4148               Dover
# 2196        Hopkinsville
# 3416            Abington
# 610           Pittsburgh
# 4636            Scranton
# 3782            Lansdale
# 1220             Kahului
# 4880             Kaneohe
# 2684             Kearney
# 854         South Valley
# 4514            Santa Fe
# 976           Winchester
# 3294          Waynesboro
# 2440           Opelousas
# 2074       Coeur d'Alene
# 2806          Post Falls
# 1830            Meridian
# 5612   Lewiston Orchards
# 5734            Meridian
# 122                 Kuna
# 5368              Moscow
# 2318             Danbury
# 5124          Cumberland
# 1342             Hanover
# 4758              Auburn
# 5490  East Hill-Meridian
# 4270            Fairwood
# 0                 Carmel
# 2928        Schererville
# 3660        Merrillville
# 3538       Michigan City
# 3172              Muncie
# 3050            Anderson
# 2562              Carmel
# 1586         Terre Haute
# 1464                Avon
# 5978         Noblesville
# 3904             Lincoln

# %%
olmkt['percent_app_download_per_pop'] = 100*(olmkt['app_download']/olmkt['population'])

# %%
olmkt.to_csv('ol_mkt_us.csv', index = False)
