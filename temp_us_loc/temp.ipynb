# %%
import pandas as pd
import geonamescache as gmc
import random

# %%
olmkt = pd.read_csv("online_mkt.csv")

# %%
# -----------------------------
# Step 1. Load US states & cities from geonamescache
# -----------------------------
gc = gmc.GeonamesCache()
us_states = gc.get_us_states()      # dict: FIPS -> {name, abbr}
cities = gc.get_cities()            # dict: geonameid -> {name, countrycode, admin1code, ...}

# Build state_name → [cities]
state_to_cities = {s["name"]: [] for s in us_states.values()}
for city in cities.values():
    if city["countrycode"] == "US":
        state_fips = city["admin1code"]
        if state_fips in us_states:
            state_name = us_states[state_fips]["name"]
            state_to_cities[state_name].append(city["name"])

# Drop states with no cities (rare)
state_to_cities = {k: v for k, v in state_to_cities.items() if v}

# -----------------------------
# Step 2. Build Brazil state → U.S. state mapping
# -----------------------------
unique_brazil_states = olmkt["state"].unique()
us_state_names = list(state_to_cities.keys())
random.shuffle(us_state_names)  # optional randomization

state_map = {
    br_state: us_state_names[i % len(us_state_names)]
    for i, br_state in enumerate(unique_brazil_states)
}

# -----------------------------
# Step 3. Build Brazil city → U.S. city mapping
# -----------------------------
city_map = {}
for _, row in olmkt.iterrows():
    br_state, br_city = row["state"], row["city"]
    us_state = state_map[br_state]

    if (br_state, br_city) not in city_map:  # assign once
        city_map[(br_state, br_city)] = random.choice(state_to_cities[us_state])

# -----------------------------
# Step 4. Apply mapping
# -----------------------------
olmkt["us_state"] = olmkt["state"].map(state_map)
olmkt["us_city"] = olmkt.apply(lambda r: city_map[(r["state"], r["city"])], axis=1)

# ----------------------------
# Step 5. Check
# ----------------------------
temp = olmkt.loc[:, olmkt.columns.str.contains("state|city")].drop_duplicates()
temp.sort_values('state')
# Out:
#                          city                state              us_state  \
# 1952                   maceio              alagoas               Wyoming
# 5246                   macapa                amapa             Louisiana
# 732                    manaus             amazonas               Arizona
# 4026         feira_de_santana                bahia              Arkansas
# 366                  salvador                bahia              Arkansas
# 488                 fortaleza                ceara            New Mexico
# 244                  brasilia     distrito_federal          Pennsylvania
# 5002                    serra       espirito_santo                Alaska
# 5856               vila_velha       espirito_santo                Alaska
# 4392     aparecida_de_goiania                goias                Kansas
# 1098                  goiania                goias                Kansas
# 1708                 sao_luis             maranhao                Nevada
# 4148                   cuiaba          mato_grosso             Minnesota
# 2196             campo_grande   mato_grosso_do_sul               Vermont
# 3416               uberlandia         minas_gerais        North Carolina
# 610            belo_horizonte         minas_gerais        North Carolina
# 4636             juiz_de_fora         minas_gerais        North Carolina
# 3782                 contagem         minas_gerais        North Carolina
# 1220                    belem                 para              Kentucky
# 4880               ananindeua                 para              Kentucky
# 2684              joao_pessoa              paraiba               Montana
# 854                  curitiba               parana         New Hampshire
# 4514                 londrina               parana         New Hampshire
# 976                    recife           pernambuco                 Idaho
# 3294  jaboatao_dos_guararapes           pernambuco                 Idaho
# 2440                 teresina                piaui                  Ohio
# 2074          duque_de_caxias       rio_de_janeiro                Oregon
# 2806              nova_iguacu       rio_de_janeiro                Oregon
# 1830              sao_goncalo       rio_de_janeiro                Oregon
# 5612             belford_roxo       rio_de_janeiro                Oregon
# 5734    campos_dos_goytacazes       rio_de_janeiro                Oregon
# 122            rio_de_janeiro       rio_de_janeiro                Oregon
# 5368                  niteroi       rio_de_janeiro                Oregon
# 2318                    natal  rio_grande_do_norte              Missouri
# 5124            caxias_do_sul    rio_grande_do_sul  District of Columbia
# 1342             porto_alegre    rio_grande_do_sul  District of Columbia
# 4758              porto_velho             rondonia              Virginia
# 5490            florianopolis       santa_catarina        South Carolina
# 4270                joinville       santa_catarina        South Carolina
# 0                   sao_paulo            sao_paulo            Washington
# 2928      sao_jose_dos_campos            sao_paulo            Washington
# 3660                 sorocaba            sao_paulo            Washington
# 3538                   osasco            sao_paulo            Washington
# 3172           ribeirao_preto            sao_paulo            Washington
# 3050              santo_andre            sao_paulo            Washington
# 2562    sao_bernardo_do_campo            sao_paulo            Washington
# 1586                 campinas            sao_paulo            Washington
# 1464                guarulhos            sao_paulo            Washington
# 5978                     maua            sao_paulo            Washington
# 3904                  aracaju              sergipe                 Texas
#
#                           us_city
# 1952                      Laramie
# 5246                      Sulphur
# 732                      Avondale
# 4026                   Springdale
# 366                    Pine Bluff
# 488                    Alamogordo
# 244                   Wilkinsburg
# 5002                       Badger
# 5856                  Eagle River
# 4392                  Leavenworth
# 1098                        Derby
# 1708                      Pahrump
# 4148                        Eagan
# 2196                   Burlington
# 3416                   Wilmington
# 610                          Cary
# 4636                   Greensboro
# 3782                    Lexington
# 1220               Saint Matthews
# 4880                     Erlanger
# 2684                  Great Falls
# 854                       Concord
# 4514                    Merrimack
# 976                     Pocatello
# 3294                     Lewiston
# 2440                 Steubenville
# 2074                 Happy Valley
# 2806                    West Linn
# 1830                   The Dalles
# 5612                 Forest Grove
# 5734                    Beaverton
# 122                     Milwaukie
# 5368                   The Dalles
# 2318                  Creve Coeur
# 5124                   Washington
# 1342                 Adams Morgan
# 4758                     Staunton
# 5490                  Goose Creek
# 4270                       Sumter
# 0                       Wenatchee
# 2928  Picnic Point-North Lynnwood
# 3660                    Washougal
# 3538                 Frederickson
# 3172                        Lacey
# 3050            Bainbridge Island
# 2562            Mountlake Terrace
# 1586                      Olympia
# 1464            Bainbridge Island
# 5978                   Tri-Cities
# 3904                Wichita Falls

# %%
olmkt.to_csv('ol_mkt_us.csv', index = False)
